# %% [markdown]
# # H3 Boundary Coverage Demo
#
# This notebook demonstrates how to cover the **boundary** (perimeter) of an arbitrary polygon with H3 cells at a specific resolution.
#
# This is useful when you want to trace a shape without filling its interior, which is much more efficient for high resolutions (like Res 15).

# %%
import h3
import folium
from shapely.geometry import Polygon, mapping
import h3_toolkit  # Using toolkit for visualization helpers if needed, though mostly standard h3 here

# 1. Define a Sample Polygon (San Francisco Area)
# format: list of [lng, lat]
polygon_coords = [
    [-122.42, 37.77], 
    [-122.41, 37.77], 
    [-122.41, 37.76], 
    [-122.42, 37.76], 
    [-122.42, 37.77]  # Close the loop
]

sample_polygon = {
    "type": "Polygon",
    "coordinates": [polygon_coords]
}

# Center for map
center_lat, center_lng = 37.765, -122.415

# %% [markdown]
# ## Algorithm: "Walk the Line"
#
# To trace the boundary:
# 1. Iterate through every pair of vertices $(p_i, p_{i+1})$.
# 2. Find the H3 cell for each vertex.
# 3. Use `h3.grid_path_cells()` to find the line of hexagons connecting them.
# 4. Union all these paths.

# %%
def get_boundary_cells(polygon_geojson, res):
    # 1. Get the list of coordinates (the ring)
    coords = polygon_geojson['coordinates'][0]
    
    boundary_cells = set()
    
    # 2. Walk through every pair of points
    for i in range(len(coords) - 1):
        p1 = coords[i]      # [lng, lat]
        p2 = coords[i+1]    # [lng, lat]
        
        # Get the cell at each vertex
        # Note: h3.latlng_to_cell expects (lat, lng)
        c1 = h3.latlng_to_cell(p1[1], p1[0], res)
        c2 = h3.latlng_to_cell(p2[1], p2[0], res)
        
        # 3. Connect them with a line of cells
        try:
            path = h3.grid_path_cells(c1, c2)
            boundary_cells.update(path)
        except Exception as e:
            # Fallback for very long distances or edge cases
            print(f"Warning: could not compute path between {c1} and {c2}: {e}")
            boundary_cells.add(c1)
            boundary_cells.add(c2)
            
    return boundary_cells

# %% [markdown]
# ## Visualize the Result
#
# We use **Resolution 11** for this demo so you can clearly see the cells on the map.
# (Resolution 15 is valid but extremely small, making it hard to see without zooming in very far).

# %%
# 1. Calculate Boundary Cells at Res 11
target_res = 11
boundary_cells = get_boundary_cells(sample_polygon, target_res)
print(f"Found {len(boundary_cells)} cells covering the boundary at Res {target_res}")

# 2. Visualize
m = folium.Map(location=[center_lat, center_lng], zoom_start=15, tiles='CartoDB positron')

# Draw the original Polygon (Blue Outline)
folium.GeoJson(
    sample_polygon,
    style_function=lambda x: {'color': 'blue', 'fillOpacity': 0.1, 'weight': 2},
    name="Target Polygon"
).add_to(m)

# Draw the Boundary Cells (Red)
# We convert each cell to its boundary polygon for display
for cell in boundary_cells:
    boundary = h3.cell_to_boundary(cell)
    # Swap (lat, lng) to (lng, lat)
    boundary_lnglat = [[(p[1], p[0]) for p in boundary]]
    # Close the loop
    boundary_lnglat[0].append(boundary_lnglat[0][0])
    poly = {"type": "Polygon", "coordinates": boundary_lnglat}
    feature = {"type": "Feature", "geometry": poly, "properties": {}}
    folium.GeoJson(
        feature,
        style_function=lambda x: {'color': 'red', 'fillOpacity': 0.6, 'weight': 0}
    ).add_to(m)

m
# Out:
# Found 85 cells covering the boundary at Res 11
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_26edcf4c183c381e21527a5249046e4f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_26edcf4c183c381e21527a5249046e4f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_26edcf4c183c381e21527a5249046e4f = L.map(
#                 &quot;map_26edcf4c183c381e21527a5249046e4f&quot;,
#                 {
#                     center: [37.765, -122.415],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 15,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d45959dd41bd237ae748192cf625f87f = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d45959dd41bd237ae748192cf625f87f.addTo(map_26edcf4c183c381e21527a5249046e4f);
#
#
#         function geo_json_cf9ffc7a285f36d6e0cdfee0b6a2b187_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.1, &quot;weight&quot;: 2};
#             }
#         }
#
#         function geo_json_cf9ffc7a285f36d6e0cdfee0b6a2b187_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_cf9ffc7a285f36d6e0cdfee0b6a2b187 = L.geoJson(null, {
#                 onEachFeature: geo_json_cf9ffc7a285f36d6e0cdfee0b6a2b187_onEachFeature,
#
#                 style: geo_json_cf9ffc7a285f36d6e0cdfee0b6a2b187_styler,
#             ...{
# }
#         });
#
#         function geo_json_cf9ffc7a285f36d6e0cdfee0b6a2b187_add (data) {
#             geo_json_cf9ffc7a285f36d6e0cdfee0b6a2b187
#                 .addData(data);
#         }
#             geo_json_cf9ffc7a285f36d6e0cdfee0b6a2b187_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[-122.42, 37.77], [-122.41, 37.77], [-122.41, 37.76], [-122.42, 37.76], [-122.42, 37.77]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#
#
#
#             geo_json_cf9ffc7a285f36d6e0cdfee0b6a2b187.addTo(map_26edcf4c183c381e21527a5249046e4f);
#
#
#         function geo_json_393506087fa8af5d6b4ebbf6d6727f54_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.6, &quot;weight&quot;: 0};
#             }
#         }
#
#         function geo_json_393506087fa8af5d6b4ebbf6d6727f54_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_393506087fa8af5d6b4ebbf6d6727f54 = L.geoJson(null, {
#                 onEachFeature: geo_json_393506087fa8af5d6b4ebbf6d6727f54_onEachFeature,
#
#                 style: geo_json_393506087fa8af5d6b4ebbf6d6727f54_styler,
#             ...{
# }
#         });
#
#         function geo_json_393506087fa8af5d6b4ebbf6d6727f54_add (data) {
#             geo_json_393506087fa8af5d6b4ebbf6d6727f54
#                 .addData(data);
#         }
#             geo_json_393506087fa8af5d6b4ebbf6d6727f54_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[-122.40983065889338, 37.76935701548832], [-122.40967759421537, 37.769597401779876], [-122.40985751965682, 37.76981237184034], [-122.41019050975568, 37.76978695513308], [-122.41034357301884, 37.769546568838784], [-122.41016364759801, 37.76933159925451], [-122.40983065889338, 37.76935701548832]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#
#
#
#             geo_json_393506087fa8af5d6b4ebbf6d6727f54.addTo(map_26edcf4c183c381e21527a5249046e4f);
#
#
#         function geo_json_3999aed7977eea03e318545647dd9414_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.6, &quot;weight&quot;: 0};
#             }
#         }
#
#         function geo_json_3999aed7977eea03e318545647dd9414_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_3999aed7977eea03e318545647dd9414 = L.geoJson(null, {
#                 onEachFeature: geo_json_3999aed7977eea03e318545647dd9414_onEachFeature,
#
#                 style: geo_json_3999aed7977eea03e318545647dd9414_styler,
#             ...{
# }
#         });
#
#         function geo_json_3999aed7977eea03e318545647dd9414_add (dat

# %% [markdown]
# ## "Real Shape" Visualization
# Using `h3_toolkit` to visualize the merged boundary of these cells.
# This creates a single "jagged ring" polygon.

# %%
# Convert the set of cells into a single merged MultiPolygon
from shapely.geometry import shape, mapping
from shapely.ops import unary_union

    # Convert to shapely Polygons (swap lat,lng to lng,lat)
    polys = []
    for c in boundary_cells:
        boundary = h3.cell_to_boundary(c)
        boundary_lnglat = [(p[1], p[0]) for p in boundary]
        polys.append(Polygon(boundary_lnglat))
merged_boundary = unary_union(polys)

m2 = folium.Map(location=[center_lat, center_lng], zoom_start=15, tiles='CartoDB positron')

# Original
folium.GeoJson(
    sample_polygon,
    style_function=lambda x: {'color': 'blue', 'fillOpacity': 0.1, 'weight': 1}
).add_to(m2)

# Merged Boundary Trace (Orange)
folium.GeoJson(
    mapping(merged_boundary),
    style_function=lambda x: {'color': 'orange', 'fillOpacity': 0.6, 'weight': 2}
).add_to(m2)

m2
# Out:
#   Cell In[10], line 6
#     polys = []
#     ^
# IndentationError: unexpected indent
